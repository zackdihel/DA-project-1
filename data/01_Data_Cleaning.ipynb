# %% [markdown]
# <a href="https://colab.research.google.com/github/zackdihel/DA-project-1/blob/main/data/01_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("Duflo data.csv")

# %%
df
# Out:
#        yeduc  p105  birthyr  birthprov  p509kab  weight  p607  classwk  \
# 0          5     2     1971         11        1     131    17        4
# 1          6     2     1959         11        1     131    33        4
# 2         11     1     1954         11        1     195    91        4
# 3         17     2     1954         11        1     131    91        4
# 4          9     2     1964         11        1     131    33        4
# ...      ...   ...      ...        ...      ...     ...   ...      ...
# 60658      6     2     1963         82       71      25    95        4
# 60659     12     2     1969         82       71     515    39        4
# 60660      3     1     1968         82       71      56    75        4
# 60661     12     1     1970         82       71      56    34        4
# 60662     12     1     1958         82       71     102    83        4
#
#          wage  birthpl  ...  dum   moldyed  java  urban  year  age74  old  \
# ...
